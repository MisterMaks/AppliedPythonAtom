# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas — программная библиотека на языке Python для обработки и анализа данных. Работа pandas с данными строится поверх библиотеки NumPy.

# %% [markdown]
# Мы сейчас рассмотрим следующее:
#     - посмотрим два объекта из библиотеки pandas: Series и DataFrame.
#     - пощупаем что это вообще такое.

# %% [raw]
# Series - объект похожий на list в питоне, он упорядочен и туда можно положить что угодно)
# Однако на деле объект Series больше похож на упорядоченный словарь OrderedDict,
# тк у Series помимо значений есть еще и индексы.

# %%
a = pd.Series(data=['амир', 'миша', 'илья', 'зарина', 'игорь'])

# %%
# в строковом представлении в столбце слева - индексы, справа - значения.
a
# Out:
# 0      амир
# 1      миша
# 2      илья
# 3    зарина
# 4     игорь
# dtype: object

# %%
# мы можем создавать серии со своей индексацией

a = pd.Series(data=['амир', 'миша', 'илья', 'зарина', 'игорь'], 
              index=[101,102,103,104,105])

# %%
# и обращаться по индексу

a[103]
# Out:
# 'илья'

# %%
# внутри все хранится в виде np.array

a.values
# Out:
# array(['амир', 'миша', 'илья', 'зарина', 'игорь'], dtype=object)

# %%
a.index
# Out:
# Int64Index([101, 102, 103, 104, 105], dtype='int64')

# %%
# мы можем создать Series вот так:

a = pd.Series({'a': 1, 'b': 2, 'c': 3, 'd': 4})

# %%
a
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
# мы можем на лету поменять индекс

a.index=[1,2,3,4]

# %%
a
# Out:
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
# у Series есть поле name

a.name='fofoofof'

# %%
a
# Out:
# 1    1
# 2    2
# 3    3
# 4    4
# Name: fofoofof, dtype: int64

# %%
a.mean()
# Out:
# 2.5

# %%
a.median()
# Out:
# 2.5

# %%
a.quantile(q=0.7)
# Out:
# 3.0999999999999996

# %%
np.sqrt(a)
# Out:
# 1    1.000000
# 2    1.414214
# 3    1.732051
# 4    2.000000
# Name: fofoofof, dtype: float64

# %%
a ** 2
# Out:
# 1     1
# 2     4
# 3     9
# 4    16
# Name: fofoofof, dtype: int64

# %% [markdown]
# ___________

# %% [raw]
# DataFrame в простом случае это таблица.
# у нее есть строки и столбцы.
# столбцами в DataFrame являются объекты Series.
# у DataFrame есть индекс по строкам, который по умолчанию задается в числовом диапазоне начниая с 0.
# Индексом по столбцам является название колонок.

# %%
d = {'колонка_1': [1, 2, 3, 4, 5], 'колонка_2': ['амир', 'миша', 'илья', 'зарина', 'игорь']}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#    колонка_1 колонка_2
# 0          1      амир
# 1          2      миша
# 2          3      илья
# 3          4    зарина
# 4          5     игорь

# %%
df = pd.DataFrame({
    'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'population': [17.04, 143.5, 9.5, 45.5],
    'square': [2724902, 17125191, 207600, 603628]
}, index=['KZ', 'RU', 'BY', 'UA'])

# %%
df
# Out:
#        country  population    square
# KZ  Kazakhstan       17.04   2724902
# RU      Russia      143.50  17125191
# BY     Belarus        9.50    207600
# UA     Ukraine       45.50    603628

# %% [markdown]
# ![](https://pbpython.com/images/pandas-dataframe-shadow.png)

# %%
# пандас умеет загружать данные из разных источников.
# ниже пример загрузки из .tsv файла. 

titanik_csv = pd.read_csv('titanik.tsv', sep='|', index_col=0)

# %% [markdown]
# ##### 1. посмотреть как выглядят данные

# %%
# вывести первые n элементов (по умолчанию n=5)

titanik_csv.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [raw]
# Обратите внимание в некоторых столбцах там где встречаются цифры еще иногда встречаются значния NaN.
# По умолчанию pandas так записывает пропущенные значения (то есть в tsv файле там ничего не было) -
# это нормальная ситуация для анализа данных (где то просто не получилось найти данные)

# %%
# вывести 10 последних элементов (по умолчанию 5)

titanik_csv.tail(n=10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                       Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# 1299      1      0    2659  14.4542   NaN        C    C    NaN       NaN
# 1300      1      0    2659  14.4542   NaN        C  NaN    NaN       NaN
# 1301      0      0    2628   7.2250   NaN        C  NaN  312.0       NaN
# 1302      0      0    2647   7.2250   NaN        C  NaN    NaN       NaN
# 1303      0      0    2627  14.4583   NaN        C  NaN    NaN       NaN
# 1304      1      0    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305      1      0    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306      0      0    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307      0      0    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308      0      0  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
# вывести 10 случайных элементов (по умолчанию 5)

titanik_csv.sample(n=10)
# Out:
#       pclass  survived                                               name  \
# 755        3         0                                 Davies, Mr. Joseph
# 93         1         1                              Dodge, Dr. Washington
# 146        1         1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 118        1         0                        Franklin, Mr. Thomas Parham
# 412        2         0                               Fynney, Mr. Joseph J
# 1014       3         0            Meek, Mrs. Thomas (Annie Louise Rowley)
# 111        1         1                     Fortune, Miss. Alice Elizabeth
# 785        3         1  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...
# 310        1         0                           Wick, Mr. George Dennick
# 1105       3         0                           Panula, Mr. Jaako Arnold
#
#          sex   age  sibsp  parch     ticket      fare        cabin embarked  \
# 755     male  17.0      2      0  A/4 48873    8.0500          NaN        S
# 93      male  53.0      1      1      33638   81.8583          A34        S
# 146   female  49.0      1      0   PC 17572   76.7292          D33        C
# 118     male   NaN      0      0     113778   26.5500          D34        S
# 412     male  35.0      0      0     239865   26.0000          NaN        S
# 1014  female   NaN      0      0     343095    8.0500          NaN        S
# 111   female  24.0      3      2      19950  263.0000  C23 C25 C27        S
# 785   female  22.0      1      0     347072   13.9000          NaN        S
# 310     male  57.0      1      1      36928  164.8667          NaN        S
# 1105    male  14.0      4      1    3101295   39.6875          NaN        S
#
#      boat   body                           home.dest
# 755   NaN    NaN  West Bromwich, England Pontiac, MI
# 93     13    NaN                   San Francisco, CA
# 146     3    NaN                        New York, NY
# 118   NaN    NaN             Westcliff-on-Sea, Essex
# 412   NaN  322.0            Liverpool / Montreal, PQ
# 1014  NaN    NaN                                 NaN
# 111    10    NaN                        Winnipeg, MB
# 785    16    NaN                      West Haven, CT
# 310   NaN    NaN                      Youngstown, OH
# 1105  NaN    NaN                                 NaN

# %%
# тк pandas сделан на основе numpy, то мы можем так же стандартно посмотреть размерность таблички через
# свойство shape

titanik_csv.shape
# Out:
# (1309, 14)

# %% [markdown]
# >  мы видим что у нас 1309 строк и 14 колонок

# %%
# мы в силах посмотреть всю табличку целиком.

titanik_csv
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22         1         1                              Behr, Mr. Karl Howell
# 23         1         1                              Bidois, Miss. Rosalie
# 24         1         1                                  Bird, Miss. Ellen
# 25         1         0                                Birnbaum, Mr. Jakob
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28         1         1                             Bissette, Miss. Amelia
# 29         1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ...      ...       ...                                                ...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                    Vovk, Mr. Janko
# 1281       3         0                               Waelens, Mr. Achille
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1285       3         0                                Wenzel, Mr. Linhart
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                   Widegren, Mr. Carl/Charles Peter
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1294       3         0                               Williams, Mr. Leslie
# 1295       3         0                                Windelov, Mr. Einar
# 1296       3         0                                   Wirz, Mr. Albert
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                               Youseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1307       3         0                                Zakarian, Mr. Ortin
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch            ticket      fare    cabin  \
# 0     female  29.0000      0      0             24160  211.3375       B5
# 1       male   0.9167      1      2            113781  151.5500  C22 C26
# 2     female   2.0000      1      2            113781  151.5500  C22 C26
# 3       male  30.0000      1      2            113781  151.5500  C22 C26
# 4     female  25.0000      1      2            113781  151.5500  C22 C26
# 5       male  48.0000      0      0             19952   26.5500      E12
# 6     female  63.0000      1      0             13502   77.9583       D7
# 7       male  39.0000      0      0            112050    0.0000      A36
# 8     female  53.0000      2      0             11769   51.4792     C101
# 9       male  71.0000      0      0          PC 17609   49.5042      NaN
# 10      male  47.0000      1      0          PC 17757  227.5250  C62 C64
# 11    female  18.0000      1      0          PC 17757  227.5250  C62 C64
# 12    female  24.0000      0      0          PC 17477   69.3000      B35
# 13    female  26.0000      0      0             19877   78.8500      NaN
# 14      male  80.0000      0      0             27042   30.0000      A23
# 15      male      NaN      0      0          PC 17318   25.9250      NaN
# 16      male  24.0000      0      1          PC 17558  247.5208  B58 B60
# 17    female  50.0000      0      1          PC 17558  247.5208  B58 B60
# 18    female  32.0000      0      0             11813   76.2917      D15
# 19      male  36.0000      0      0             13050   75.2417       C6
# 20      male  37.0000      1      1             11751   52.5542      D35
# 21    female  47.0000      1      1             11751   52.5542      D35
# 22      male  26.0000      0      0            111369   30.0000     C148
# 23    female  42.0000      0      0          PC 17757  227.5250      NaN
# 24    female  29.0000      0      0          PC 17483  221.7792      C97
# 25      male  25.0000      0      0             13905   26.0000      NaN
# 26      male  25.0000      1      0             11967   91.0792      B49
# 27    female  19.0000      1      0             11967   91.0792      B49
# 28    female  35.0000      0      0          PC 17760  135.6333      C99
# 29      male  28.0000      0      0            110564   26.5500      C52
# ...      ...      ...    ...    ...               ...       ...      ...
# 1279  female  14.0000      0      0            350406    7.8542      NaN
# 1280    male  22.0000      0      0            349252    7.8958      NaN
# 1281    male  22.0000      0      0            345767    9.0000      NaN
# 1282    male      NaN      0      0            359309    8.0500      NaN
# 1283    male      NaN      0      0        C.A. 49867    7.5500      NaN
# 1284    male      NaN      0      0  SOTON/OQ 3101316    8.0500      NaN
# 1285    male  32.5000      0      0            345775    9.5000      NaN
# 1286  female  38.0000      0      0              2688    7.2292      NaN
# 1287    male  51.0000      0      0            347064    7.7500      NaN
# 1288    male  18.0000      1      0           3101267    6.4958      NaN
# 1289    male  21.0000      1      0           3101266    6.4958      NaN
# 1290  female  47.0000      1      0            363272    7.0000      NaN
# 1291    male      NaN      0      0              3410    8.7125      NaN
# 1292    male      NaN      0      0     S.O./P.P. 751    7.5500      NaN
# 1293    male      NaN      0      0          A/5 2466    8.0500      NaN
# 1294    male  28.5000      0      0             54636   16.1000      NaN
# 1295    male  21.0000      0      0  SOTON/OQ 3101317    7.2500      NaN
# 1296    male  27.0000      0      0            315154    8.6625      NaN
# 1297    male      NaN      0      0        A/4. 34244    7.2500      NaN
# 1298    male  36.0000      0      0            345771    9.5000      NaN
# 1299    male  27.0000      1      0              2659   14.4542      NaN
# 1300  female  15.0000      1      0              2659   14.4542      NaN
# 1301    male  45.5000      0      0              2628    7.2250      NaN
# 1302    male      NaN      0      0              2647    7.2250      NaN
# 1303    male      NaN      0      0              2627   14.4583      NaN
# 1304  female  14.5000      1      0              2665   14.4542      NaN
# 1305  female      NaN      1      0              2665   14.4542      NaN
# 1306    male  26.5000      0      0              2656    7.2250      NaN
# 1307    male  27.0000      0      0              2670    7.2250      NaN
# 1308    male  29.0000      0      0            315082    7.8750      NaN
#
#      embarked boat   body                           home.dest
# 0           S    2    NaN                        St Louis, MO
# 1           S   11    NaN     Montreal, PQ / Chesterville, ON
# 2           S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 3           S  NaN  135.0     Montreal, PQ / Chesterville, ON
# 4           S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 5           S    3    NaN                        New York, NY
# 6           S   10    NaN                          Hudson, NY
# 7           S  NaN    NaN                         Belfast, NI
# 8           S    D    NaN                 Bayside, Queens, NY
# 9           C  NaN   22.0                 Montevideo, Uruguay
# 10          C  NaN  124.0                        New York, NY
# 11          C    4    NaN                        New York, NY
# 12          C    9    NaN                       Paris, France
# 13          S    6    NaN                                 NaN
# 14          S    B    NaN                       Hessle, Yorks
# 15          S  NaN    NaN                        New York, NY
# 16          C  NaN    NaN                        Montreal, PQ
# 17          C    6    NaN                        Montreal, PQ
# 18          C    8    NaN                                 NaN
# 19          C    A    NaN                        Winnipeg, MN
# 20          S    5    NaN                        New York, NY
# 21          S    5    NaN                        New York, NY
# 22          C    5    NaN                        New York, NY
# 23          C    4    NaN                                 NaN
# 24          S    8    NaN                                 NaN
# 25          C  NaN  148.0                   San Francisco, CA
# 26          C    7    NaN                        Dowagiac, MI
# 27          C    7    NaN                        Dowagiac, MI
# 28          S    8    NaN                                 NaN
# 29          S    D    NaN  Stockholm, Sweden / Washington, DC
# ...       ...  ...    ...                                 ...
# 1279        S  NaN    NaN                                 NaN
# 1280        S  NaN    NaN                                 NaN
# 1281        S  NaN    NaN      Antwerp, Belgium / Stanton, OH
# 1282        S  NaN    NaN                                 NaN
# 1283        S  NaN    NaN                                 NaN
# 1284        S  NaN    NaN                                 NaN
# 1285        S  NaN  298.0                                 NaN
# 1286        C    C    NaN                                 NaN
# 1287        S  NaN    NaN                                 NaN
# 1288        S  NaN  314.0                                 NaN
# 1289        S  NaN    NaN                                 NaN
# 1290        S  NaN    NaN                                 NaN
# 1291        S  NaN    NaN                                 NaN
# 1292        S  NaN    NaN                                 NaN
# 1293        S  NaN    NaN                                 NaN
# 1294        S  NaN   14.0                                 NaN
# 1295        S  NaN    NaN                                 NaN
# 1296        S  NaN  131.0                                 NaN
# 1297        S  NaN    NaN                                 NaN
# 1298        S  NaN    NaN                                 NaN
# 1299        C    C    NaN                                 NaN
# 1300        C  NaN    NaN                                 NaN
# 1301        C  NaN  312.0                                 NaN
# 1302        C  NaN    NaN                                 NaN
# 1303        C  NaN    NaN                                 NaN
# 1304        C  NaN  328.0                                 NaN
# 1305        C  NaN    NaN                                 NaN
# 1306        C  NaN  304.0                                 NaN
# 1307        C  NaN    NaN                                 NaN
# 1308        S  NaN    NaN                                 NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# вы конечно можете посмотреть почти всю табличку целиком, вас ограничивают настройки отображения табличек в пандасе.
#
# > это поля
#
# > pd.options.display.max_columns - максимальное число колонок которое будет отрисовано
#
# > pd.options.display.max_rows - максимальное число строк которое будет отрисовано
#
# конечно же как программисты мы можем все это поменять.

# %%
pd.options.display.max_columns = 5

# %%
pd.options.display.max_rows = 20

# %%
# стало хуже?

titanik_csv
# Out:
#       pclass  survived  ...   body                        home.dest
# 0          1         1  ...    NaN                     St Louis, MO
# 1          1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 5          1         1  ...    NaN                     New York, NY
# 6          1         1  ...    NaN                       Hudson, NY
# 7          1         0  ...    NaN                      Belfast, NI
# 8          1         1  ...    NaN              Bayside, Queens, NY
# 9          1         0  ...   22.0              Montevideo, Uruguay
# ...      ...       ...  ...    ...                              ...
# 1299       3         0  ...    NaN                              NaN
# 1300       3         1  ...    NaN                              NaN
# 1301       3         0  ...  312.0                              NaN
# 1302       3         0  ...    NaN                              NaN
# 1303       3         0  ...    NaN                              NaN
# 1304       3         0  ...  328.0                              NaN
# 1305       3         0  ...    NaN                              NaN
# 1306       3         0  ...  304.0                              NaN
# 1307       3         0  ...    NaN                              NaN
# 1308       3         0  ...    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
# поставим чтоб было удобнее
pd.options.display.max_columns = 20
pd.options.display.max_rows = 200 # рекомендую ставить большое значение только если у вас мощный комп)

# %% [markdown]
# ##### 2. начнем смотреть столбцы ближе.

# %% [markdown]
# Для того чтобы понять какой столбец (признак) что означает почитайте об этом в разделе Data
# https://www.kaggle.com/c/titanic/data .
#
# Пока вы не запомните, может быть полезно выписать название всех столбцов и что они значат прямо в нотбук - сюда:
#
# * Survived -
# * Pclass -
# * Name -
# * Sex -
# * Age -
# * SibSp -
# * Parch -
# * Ticket -
# * Fare -
# * Cabin -
# * Embarked -

# %% [markdown]
# несколько полезных методов которые помогут быстро посмотреть общие характеристики данных:
#
# 1. .describe() - Выведет количество, среднее, стандартное отклонение, квантили, минимум и максимум всех **числовых признаков** (столбцов)
# 2. .columns - это поле а не метод (в конце скобки не надо писать). Выведет название всех колонок.
# 3. .count() - выведет количесто **не пропущенных** значений в каждом столбце (not nan значений)
# 4. .nunique() - выведет количество уникальных значений в каждом столбце
# 5. .dtypes - это поле а не метод (в конце скобки не надо писать). Выведет тип переменной хранящейся в каждом столбце

# %%
titanik_csv.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanik_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 153.4+ KB

# %%
titanik_csv.count()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
titanik_csv.nunique()
# Out:
# pclass          3
# survived        2
# name         1307
# sex             2
# age            98
# sibsp           7
# parch           8
# ticket        929
# fare          281
# cabin         186
# embarked        3
# boat           27
# body          121
# home.dest     369
# dtype: int64

# %%
# там где строки пандас по умолчанию пишет object
# иногда полезно посмотреть что тут.

titanik_csv.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Я делаль и не сработало :(

titanik_csv.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-e083d3a9c549> in <module>
# ----> 1 titanik_csv.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %% [markdown]
# мы можем напрямую обращаться к столбцу, столбцам, строке и строкам.
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html

# %%
# самый простой способ обратиться к столбцу - это написать его название через точку
# давайте обратимся к полю sex
# нам вернется pd.Series - прямо вся колонка

titanik_csv.sex
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13      female
# 14        male
# 15        male
# 16        male
# 17      female
# 18      female
# 19        male
# 20        male
# 21      female
# 22        male
# 23      female
# 24      female
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
# 30        male
# 31        male
# 32      female
# 33      female
# 34        male
# 35      female
# 36      female
# 37        male
# 38        male
# 39        male
# 40        male
# 41      female
# 42      female
# 43      female
# 44      female
# 45        male
# 46        male
# 47        male
# 48      female
# 49        male
# 50      female
# 51        male
# 52        male
# 53        male
# 54        male
# 55      female
# 56        male
# 57      female
# 58        male
# 59      female
# 60        male
# 61      female
# 62        male
# 63      female
# 64        male
# 65      female
# 66      female
# 67      female
# 68        male
# 69      female
# 70        male
# 71        male
# 72      female
# 73      female
# 74        male
# 75        male
# 76      female
# 77        male
# 78      female
# 79      female
# 80        male
# 81        male
# 82      female
# 83      female
# 84        male
# 85      female
# 86        male
# 87        male
# 88      female
# 89        male
# 90      female
# 91        male
# 92      female
# 93        male
# 94        male
# 95      female
# 96        male
# 97      female
# 98      female
# 99      female
#          ...
# 1209    female
# 1210      male
# 1211    female
# 1212      male
# 1213      male
# 1214      male
# 1215      male
# 1216    female
# 1217      male
# 1218      male
# 1219      male
# 1220      male
# 1221      male
# 1222      male
# 1223    female
# 1224      male
# 1225      male
# 1226      male
# 1227    female
# 1228      male
# 1229      male
# 1230    female
# 1231    female
# 1232      male
# 1233      male
# 1234      male
# 1235      male
# 1236      male
# 1237      male
# 1238      male
# 1239      male
# 1240      male
# 1241      male
# 1242      male
# 1243      male
# 1244    female
# 1245      male
# 1246      male
# 1247    female
# 1248      male
# 1249      male
# 1250      male
# 1251      male
# 1252      male
# 1253      male
# 1254      male
# 1255      male
# 1256      male
# 1257    female
# 1258    female
# 1259      male
# 1260    female
# 1261    female
# 1262      male
# 1263      male
# 1264      male
# 1265    female
# 1266      male
# 1267    female
# 1268      male
# 1269      male
# 1270      male
# 1271      male
# 1272      male
# 1273    female
# 1274      male
# 1275      male
# 1276    female
# 1277      male
# 1278      male
# 1279    female
# 1280      male
# 1281      male
# 1282      male
# 1283      male
# 1284      male
# 1285      male
# 1286    female
# 1287      male
# 1288      male
# 1289      male
# 1290    female
# 1291      male
# 1292      male
# 1293      male
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
# еще можно обратиться через квадратные скобки
# эффект будет совершенно таким же

titanik_csv["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13      female
# 14        male
# 15        male
# 16        male
# 17      female
# 18      female
# 19        male
# 20        male
# 21      female
# 22        male
# 23      female
# 24      female
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
# 30        male
# 31        male
# 32      female
# 33      female
# 34        male
# 35      female
# 36      female
# 37        male
# 38        male
# 39        male
# 40        male
# 41      female
# 42      female
# 43      female
# 44      female
# 45        male
# 46        male
# 47        male
# 48      female
# 49        male
# 50      female
# 51        male
# 52        male
# 53        male
# 54        male
# 55      female
# 56        male
# 57      female
# 58        male
# 59      female
# 60        male
# 61      female
# 62        male
# 63      female
# 64        male
# 65      female
# 66      female
# 67      female
# 68        male
# 69      female
# 70        male
# 71        male
# 72      female
# 73      female
# 74        male
# 75        male
# 76      female
# 77        male
# 78      female
# 79      female
# 80        male
# 81        male
# 82      female
# 83      female
# 84        male
# 85      female
# 86        male
# 87        male
# 88      female
# 89        male
# 90      female
# 91        male
# 92      female
# 93        male
# 94        male
# 95      female
# 96        male
# 97      female
# 98      female
# 99      female
#          ...
# 1209    female
# 1210      male
# 1211    female
# 1212      male
# 1213      male
# 1214      male
# 1215      male
# 1216    female
# 1217      male
# 1218      male
# 1219      male
# 1220      male
# 1221      male
# 1222      male
# 1223    female
# 1224      male
# 1225      male
# 1226      male
# 1227    female
# 1228      male
# 1229      male
# 1230    female
# 1231    female
# 1232      male
# 1233      male
# 1234      male
# 1235      male
# 1236      male
# 1237      male
# 1238      male
# 1239      male
# 1240      male
# 1241      male
# 1242      male
# 1243      male
# 1244    female
# 1245      male
# 1246      male
# 1247    female
# 1248      male
# 1249      male
# 1250      male
# 1251      male
# 1252      male
# 1253      male
# 1254      male
# 1255      male
# 1256      male
# 1257    female
# 1258    female
# 1259      male
# 1260    female
# 1261    female
# 1262      male
# 1263      male
# 1264      male
# 1265    female
# 1266      male
# 1267    female
# 1268      male
# 1269      male
# 1270      male
# 1271      male
# 1272      male
# 1273    female
# 1274      male
# 1275      male
# 1276    female
# 1277      male
# 1278      male
# 1279    female
# 1280      male
# 1281      male
# 1282      male
# 1283      male
# 1284      male
# 1285      male
# 1286    female
# 1287      male
# 1288      male
# 1289      male
# 1290    female
# 1291      male
# 1292      male
# 1293      male
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
# через values мы можем получить np.array который хранится в вернувшемся объекте pd.Series

titanik_csv.sex.values
# Out:
# array(['female', 'male', 'female', ..., 'male', 'male', 'male'],
#       dtype=object)

# %%
# силами pandas мы можем посмотреть различные значения содержащиеся в объекте pd.Series
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html
# обратите внимание на доп параметры этой функции

titanik_csv.sex.value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %% [markdown]
# > Вопрос Кого больше мужчин или женщин?
#
# > ответ:
#
# > Вопрос - объект какого типа возвращается после вызова  функции value_counts() ?
#
# > ответ:

# %% [markdown]
# в пандасе мы можем получить срез сразу по нескольким колонкам, тогда вернется новый DataFrame а не Series

# %%
titanik_csv[ ['sex', 'age'] ]

# %% [markdown]
# Самый каноничный способ обращения к полям - через loc или iloc
#
# loc - позволяет обратиться по названию индексов,
#
# iloc - по нумерованному значению (то есть обращаемся через цифры, начиная с нуля)

# %%
titanik_csv.loc[:, 'sex']

# %% [markdown]
# чтобы в дальнейшем экономить место - будем смотреть только первые 5 записей

# %%
titanik_csv.loc[:, 'sex'].head()
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
titanik_csv.loc[:, ['sex', 'age']].head()
# Out:
#       sex      age
# 0  female  29.0000
# 1    male   0.9167
# 2  female   2.0000
# 3    male  30.0000
# 4  female  25.0000

# %%
titanik_csv.loc[[12,13,14,17,17], ['sex', 'age']].head()
# Out:
#        sex   age
# 12  female  24.0
# 13  female  26.0
# 14    male  80.0
# 17  female  50.0
# 17  female  50.0

# %%
titanik_csv.iloc[[12,13,14,17,17], [3, 4]].head()
# Out:
#        sex   age
# 12  female  24.0
# 13  female  26.0
# 14    male  80.0
# 17  female  50.0
# 17  female  50.0

# %% [markdown]
# > копию или реальный объект возвращает лок?

# %% [markdown]
# https://stackoverflow.com/questions/47972633/in-pandas-does-iloc-method-give-a-copy-or-view

# %% [markdown]
# ##### 3. мы можем работать с полями и изменять их как хотим.¶

# %%
titanik_csv.loc[0, 'name']
# Out:
# 'Allen, Miss. Elisabeth Walton'

# %% [markdown]
# например, давайте выделим только первую часть имени.
# как мы это делаем с одной строкой?

# %%
titanik_csv.loc[0, 'name'].split(',')[0]
# Out:
# 'Allen'

# %% [markdown]
# чтобы проделать этот финт со всеми строками - не нужно итерироваться в цикле.
# достаточно применить некоторую функцию.

# %%
titanik_csv['name'].head().apply(lambda x: x.split(',')[0])
# Out:
# 0      Allen
# 1    Allison
# 2    Allison
# 3    Allison
# 4    Allison
# Name: name, dtype: object

# %% [raw]
# на основе этого мы можем создать новую колонку.

# %%
titanik_csv['only_name'] = titanik_csv['name'].apply(lambda x: x.split(',')[0])

# %%
titanik_csv.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest only_name
# 0                     St Louis, MO     Allen
# 1  Montreal, PQ / Chesterville, ON   Allison
# 2  Montreal, PQ / Chesterville, ON   Allison
# 3  Montreal, PQ / Chesterville, ON   Allison
# 4  Montreal, PQ / Chesterville, ON   Allison

# %% [markdown]
# ##### 4. мы можем удалять столбцы или строки

# %%
titanik_csv.drop(['only_name'], axis=1)

# %%
titanik_csv[list(set(titanik_csv.columns)-{'only_name'})]

# %%
titanik_csv[['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
       'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest']]

# %% [markdown]
# ##### у нас может быть головная боль - пропущенные значения.

# %%
titanik_csv.body.isna()
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9       False
# 10      False
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25      False
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39      False
# 40       True
# 41       True
# 42       True
# 43       True
# 44       True
# 45       True
# 46       True
# 47       True
# 48       True
# 49       True
# 50       True
# 51       True
# 52       True
# 53       True
# 54       True
# 55       True
# 56       True
# 57       True
# 58       True
# 59       True
# 60      False
# 61       True
# 62       True
# 63       True
# 64       True
# 65       True
# 66       True
# 67       True
# 68       True
# 69       True
# 70       True
# 71       True
# 72       True
# 73       True
# 74       True
# 75       True
# 76       True
# 77       True
# 78       True
# 79       True
# 80       True
# 81      False
# 82       True
# 83       True
# 84       True
# 85       True
# 86       True
# 87       True
# 88       True
# 89       True
# 90       True
# 91       True
# 92       True
# 93       True
# 94       True
# 95       True
# 96      False
# 97       True
# 98       True
# 99       True
#         ...
# 1209     True
# 1210     True
# 1211     True
# 1212     True
# 1213     True
# 1214     True
# 1215     True
# 1216     True
# 1217     True
# 1218     True
# 1219     True
# 1220     True
# 1221     True
# 1222     True
# 1223     True
# 1224     True
# 1225    False
# 1226     True
# 1227     True
# 1228     True
# 1229     True
# 1230     True
# 1231     True
# 1232     True
# 1233     True
# 1234     True
# 1235     True
# 1236     True
# 1237     True
# 1238     True
# 1239    False
# 1240     True
# 1241     True
# 1242     True
# 1243     True
# 1244     True
# 1245     True
# 1246     True
# 1247     True
# 1248     True
# 1249     True
# 1250     True
# 1251    False
# 1252     True
# 1253     True
# 1254     True
# 1255     True
# 1256     True
# 1257     True
# 1258     True
# 1259     True
# 1260     True
# 1261     True
# 1262     True
# 1263    False
# 1264    False
# 1265     True
# 1266     True
# 1267     True
# 1268     True
# 1269     True
# 1270     True
# 1271     True
# 1272     True
# 1273     True
# 1274     True
# 1275     True
# 1276     True
# 1277     True
# 1278     True
# 1279     True
# 1280     True
# 1281     True
# 1282     True
# 1283     True
# 1284     True
# 1285    False
# 1286     True
# 1287     True
# 1288    False
# 1289     True
# 1290     True
# 1291     True
# 1292     True
# 1293     True
# 1294    False
# 1295     True
# 1296    False
# 1297     True
# 1298     True
# 1299     True
# 1300     True
# 1301    False
# 1302     True
# 1303     True
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Name: body, Length: 1309, dtype: bool

# %%
titanik_csv.body[-titanik_csv.body.isna()]
# Out:
# 3       135.0
# 9        22.0
# 10      124.0
# 25      148.0
# 39      208.0
# 60      172.0
# 81      269.0
# 96       62.0
# 101     133.0
# 128     275.0
# 138     147.0
# 150     110.0
# 154     307.0
# 162      38.0
# 171      80.0
# 173      45.0
# 174     258.0
# 189     126.0
# 200     292.0
# 201     175.0
# 205     249.0
# 206     230.0
# 215     122.0
# 217     263.0
# 221     234.0
# 222     189.0
# 224     166.0
# 232     207.0
# 236     232.0
# 243      16.0
# 248     109.0
# 285      96.0
# 287      46.0
# 300     245.0
# 307     169.0
# 335     174.0
# 356      97.0
# 364      18.0
# 367     130.0
# 368      17.0
# 391     295.0
# 406     286.0
# 409     236.0
# 412     322.0
# 421     297.0
# 422     155.0
# 424     305.0
# 425      19.0
# 426      75.0
# 429      35.0
# 443     256.0
# 450     149.0
# 466     283.0
# 474     165.0
# 486     108.0
# 488     121.0
# 490      52.0
# 498     209.0
# 505     271.0
# 512      43.0
# 516      15.0
# 518     101.0
# 519     287.0
# 567      81.0
# 568     294.0
# 585     293.0
# 602     190.0
# 608      72.0
# 609     103.0
# 617      79.0
# 619     259.0
# 620     260.0
# 644     142.0
# 692     299.0
# 727     171.0
# 741       9.0
# 748     197.0
# 781      51.0
# 796     187.0
# 797      68.0
# 817      47.0
# 837      98.0
# 847     188.0
# 850      69.0
# 863     306.0
# 873     120.0
# 888     143.0
# 890     156.0
# 891     285.0
# 897      37.0
# 919      58.0
# 924      70.0
# 960     196.0
# 976     153.0
# 992      61.0
# 1011     53.0
# 1015    201.0
# 1024    309.0
# 1066    181.0
# 1083    173.0
# 1089     89.0
# 1096      4.0
# 1100    206.0
# 1146    327.0
# 1152    119.0
# 1153      7.0
# 1169     32.0
# 1171     67.0
# 1192    284.0
# 1225    261.0
# 1239    176.0
# 1251     50.0
# 1263      1.0
# 1264    255.0
# 1285    298.0
# 1288    314.0
# 1294     14.0
# 1296    131.0
# 1301    312.0
# 1304    328.0
# 1306    304.0
# Name: body, dtype: float64

# %%
titanik_csv.fillna(0)
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22         1         1                              Behr, Mr. Karl Howell
# 23         1         1                              Bidois, Miss. Rosalie
# 24         1         1                                  Bird, Miss. Ellen
# 25         1         0                                Birnbaum, Mr. Jakob
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28         1         1                             Bissette, Miss. Amelia
# 29         1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30         1         0                       Blackwell, Mr. Stephen Weart
# 31         1         1                                   Blank, Mr. Henry
# 32         1         1                            Bonnell, Miss. Caroline
# 33         1         1                           Bonnell, Miss. Elizabeth
# 34         1         0                           Borebank, Mr. John James
# 35         1         1                           Bowen, Miss. Grace Scott
# 36         1         1                        Bowerman, Miss. Elsie Edith
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 38         1         0                            Brady, Mr. John Bertram
# 39         1         0                                 Brandeis, Mr. Emil
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 41         1         1          Brown, Mrs. James Joseph (Margaret Tobin)
# 42         1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43         1         1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44         1         1                    Burns, Miss. Elizabeth Margaret
# 45         1         0                  Butt, Major. Archibald Willingham
# 46         1         0                              Cairns, Mr. Alexander
# 47         1         1                  Calderhead, Mr. Edward Pennington
# 48         1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 51         1         0                           Carlsson, Mr. Frans Olof
# 52         1         0                            Carrau, Mr. Francisco M
# 53         1         0                             Carrau, Mr. Jose Pedro
# 54         1         1                Carter, Master. William Thornton II
# 55         1         1                          Carter, Miss. Lucile Polk
# 56         1         1                         Carter, Mr. William Ernest
# 57         1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 58         1         0                             Case, Mr. Howard Brown
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 60         1         0                      Cavendish, Mr. Tyrell William
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 62         1         0                        Chaffee, Mr. Herbert Fuller
# 63         1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 64         1         1                      Chambers, Mr. Norman Campbell
# 65         1         1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 66         1         1                        Chaudanson, Miss. Victorine
# 67         1         1                               Cherry, Miss. Gladys
# 68         1         1                           Chevre, Mr. Paul Romaine
# 69         1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 71         1         0                           Clark, Mr. Walter Miller
# 72         1         1      Clark, Mrs. Walter Miller (Virginia McDowell)
# 73         1         1                               Cleaver, Miss. Alice
# 74         1         0                        Clifford, Mr. George Quincy
# 75         1         0                         Colley, Mr. Edward Pomeroy
# 76         1         1                        Compton, Miss. Sara Rebecca
# 77         1         0                   Compton, Mr. Alexander Taylor Jr
# 78         1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 79         1         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 80         1         0                          Crafton, Mr. John Bertram
# 81         1         0                       Crosby, Capt. Edward Gifford
# 82         1         1                            Crosby, Miss. Harriet R
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 84         1         0                          Cumings, Mr. John Bradley
# 85         1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 86         1         1                             Daly, Mr. Peter Denis
# 87         1         1                        Daniel, Mr. Robert Williams
# 88         1         1                               Daniels, Miss. Sarah
# 89         1         0                             Davidson, Mr. Thornton
# 90         1         1               Davidson, Mrs. Thornton (Orian Hays)
# 91         1         1                            Dick, Mr. Albert Adrian
# 92         1         1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 93         1         1                              Dodge, Dr. Washington
# 94         1         1                          Dodge, Master. Washington
# 95         1         1              Dodge, Mrs. Washington (Ruth Vidaver)
# 96         1         0                         Douglas, Mr. Walter Donald
# 97         1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 98         1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 99         1         1  Duff Gordon, Lady. (Lucille Christiana Sutherl...
# ...      ...       ...                                                ...
# 1209       3         0                      Skoog, Miss. Margit Elizabeth
# 1210       3         0                                 Skoog, Mr. Wilhelm
# 1211       3         0    Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 1212       3         0                               Slabenoff, Mr. Petco
# 1213       3         0                      Slocovski, Mr. Selman Francis
# 1214       3         0                                Smiljanic, Mr. Mile
# 1215       3         0                                  Smith, Mr. Thomas
# 1216       3         1                                 Smyth, Miss. Julia
# 1217       3         0         Soholt, Mr. Peter Andreas Lauritz Andersen
# 1218       3         0                      Somerton, Mr. Francis William
# 1219       3         0                                 Spector, Mr. Woolf
# 1220       3         0                            Spinner, Mr. Henry John
# 1221       3         0                                  Staneff, Mr. Ivan
# 1222       3         0                                Stankovic, Mr. Ivan
# 1223       3         1                    Stanley, Miss. Amy Zillah Elsie
# 1224       3         0                         Stanley, Mr. Edward Roland
# 1225       3         0                                 Storey, Mr. Thomas
# 1226       3         0                               Stoytcheff, Mr. Ilia
# 1227       3         0                        Strandberg, Miss. Ida Sofia
# 1228       3         1                                 Stranden, Mr. Juho
# 1229       3         0                                  Strilic, Mr. Ivan
# 1230       3         0                         Strom, Miss. Telma Matilda
# 1231       3         0         Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 1232       3         1                     Sunderland, Mr. Victor Francis
# 1233       3         1                          Sundman, Mr. Johan Julian
# 1234       3         0                             Sutehall, Mr. Henry Jr
# 1235       3         0                                Svensson, Mr. Johan
# 1236       3         1                         Svensson, Mr. Johan Cervin
# 1237       3         0                                 Svensson, Mr. Olof
# 1238       3         1                         Tenglin, Mr. Gunnar Isidor
# 1239       3         0                       Theobald, Mr. Thomas Leonard
# 1240       3         1                    Thomas, Master. Assad Alexander
# 1241       3         0                              Thomas, Mr. Charles P
# 1242       3         0                                   Thomas, Mr. John
# 1243       3         0                                Thomas, Mr. Tannous
# 1244       3         1          Thomas, Mrs. Alexander (Thamine "Thelma")
# 1245       3         0                    Thomson, Mr. Alexander Morrison
# 1246       3         0                         Thorneycroft, Mr. Percival
# 1247       3         1  Thorneycroft, Mrs. Percival (Florence Kate White)
# 1248       3         0                                 Tikkanen, Mr. Juho
# 1249       3         0                                   Tobin, Mr. Roger
# 1250       3         0                                Todoroff, Mr. Lalio
# 1251       3         0                         Tomlin, Mr. Ernest Portage
# 1252       3         0                          Torber, Mr. Ernst William
# 1253       3         0                                   Torfa, Mr. Assad
# 1254       3         1                       Tornquist, Mr. William Henry
# 1255       3         0                                  Toufik, Mr. Nakli
# 1256       3         1                     Touma, Master. Georges Youssef
# 1257       3         1                         Touma, Miss. Maria Youssef
# 1258       3         1            Touma, Mrs. Darwis (Hanne Youssef Razi)
# 1259       3         0                                Turcin, Mr. Stjepan
# 1260       3         1                            Turja, Miss. Anna Sofia
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 1262       3         0                van Billiard, Master. James William
# 1263       3         0                  van Billiard, Master. Walter John
# 1264       3         0                    van Billiard, Mr. Austin Blyler
# 1265       3         0                          Van Impe, Miss. Catharina
# 1266       3         0                        Van Impe, Mr. Jean Baptiste
# 1267       3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1268       3         0                        van Melkebeke, Mr. Philemon
# 1269       3         0                   Vande Velde, Mr. Johannes Joseph
# 1270       3         0                     Vande Walle, Mr. Nestor Cyriel
# 1271       3         0                        Vanden Steen, Mr. Leo Peter
# 1272       3         0                        Vander Cruyssen, Mr. Victor
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1274       3         0                          Vander Planke, Mr. Julius
# 1275       3         0                    Vander Planke, Mr. Leo Edmondus
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1277       3         1                               Vartanian, Mr. David
# 1278       3         0                             Vendel, Mr. Olof Edvin
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                    Vovk, Mr. Janko
# 1281       3         0                               Waelens, Mr. Achille
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1285       3         0                                Wenzel, Mr. Linhart
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                   Widegren, Mr. Carl/Charles Peter
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1294       3         0                               Williams, Mr. Leslie
# 1295       3         0                                Windelov, Mr. Einar
# 1296       3         0                                   Wirz, Mr. Albert
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                               Youseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1307       3         0                                Zakarian, Mr. Ortin
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch             ticket      fare        cabin  \
# 0     female  29.0000      0      0              24160  211.3375           B5
# 1       male   0.9167      1      2             113781  151.5500      C22 C26
# 2     female   2.0000      1      2             113781  151.5500      C22 C26
# 3       male  30.0000      1      2             113781  151.5500      C22 C26
# 4     female  25.0000      1      2             113781  151.5500      C22 C26
# 5       male  48.0000      0      0              19952   26.5500          E12
# 6     female  63.0000      1      0              13502   77.9583           D7
# 7       male  39.0000      0      0             112050    0.0000          A36
# 8     female  53.0000      2      0              11769   51.4792         C101
# 9       male  71.0000      0      0           PC 17609   49.5042            0
# 10      male  47.0000      1      0           PC 17757  227.5250      C62 C64
# 11    female  18.0000      1      0           PC 17757  227.5250      C62 C64
# 12    female  24.0000      0      0           PC 17477   69.3000          B35
# 13    female  26.0000      0      0              19877   78.8500            0
# 14      male  80.0000      0      0              27042   30.0000          A23
# 15      male   0.0000      0      0           PC 17318   25.9250            0
# 16      male  24.0000      0      1           PC 17558  247.5208      B58 B60
# 17    female  50.0000      0      1           PC 17558  247.5208      B58 B60
# 18    female  32.0000      0      0              11813   76.2917          D15
# 19      male  36.0000      0      0              13050   75.2417           C6
# 20      male  37.0000      1      1              11751   52.5542          D35
# 21    female  47.0000      1      1              11751   52.5542          D35
# 22      male  26.0000      0      0             111369   30.0000         C148
# 23    female  42.0000      0      0           PC 17757  227.5250            0
# 24    female  29.0000      0      0           PC 17483  221.7792          C97
# 25      male  25.0000      0      0              13905   26.0000            0
# 26      male  25.0000      1      0              11967   91.0792          B49
# 27    female  19.0000      1      0              11967   91.0792          B49
# 28    female  35.0000      0      0           PC 17760  135.6333          C99
# 29      male  28.0000      0      0             110564   26.5500          C52
# 30      male  45.0000      0      0             113784   35.5000            T
# 31      male  40.0000      0      0             112277   31.0000          A31
# 32    female  30.0000      0      0              36928  164.8667           C7
# 33    female  58.0000      0      0             113783   26.5500         C103
# 34      male  42.0000      0      0             110489   26.5500          D22
# 35    female  45.0000      0      0           PC 17608  262.3750            0
# 36    female  22.0000      0      1             113505   55.0000          E33
# 37      male   0.0000      0      0             111427   26.5500            0
# 38      male  41.0000      0      0             113054   30.5000          A21
# 39      male  48.0000      0      0           PC 17591   50.4958          B10
# 40      male   0.0000      0      0             112379   39.6000            0
# 41    female  44.0000      0      0           PC 17610   27.7208           B4
# 42    female  59.0000      2      0              11769   51.4792         C101
# 43    female  60.0000      0      0              11813   76.2917          D15
# 44    female  41.0000      0      0              16966  134.5000          E40
# 45      male  45.0000      0      0             113050   26.5500          B38
# 46      male   0.0000      0      0             113798   31.0000            0
# 47      male  42.0000      0      0           PC 17476   26.2875          E24
# 48    female  53.0000      0      0           PC 17606   27.4458            0
# 49      male  36.0000      0      1           PC 17755  512.3292  B51 B53 B55
# 50    female  58.0000      0      1           PC 17755  512.3292  B51 B53 B55
# 51      male  33.0000      0      0                695    5.0000  B51 B53 B55
# 52      male  28.0000      0      0             113059   47.1000            0
# 53      male  17.0000      0      0             113059   47.1000            0
# 54      male  11.0000      1      2             113760  120.0000      B96 B98
# 55    female  14.0000      1      2             113760  120.0000      B96 B98
# 56      male  36.0000      1      2             113760  120.0000      B96 B98
# 57    female  36.0000      1      2             113760  120.0000      B96 B98
# 58      male  49.0000      0      0              19924   26.0000            0
# 59    female   0.0000      0      0              17770   27.7208            0
# 60      male  36.0000      1      0              19877   78.8500          C46
# 61    female  76.0000      1      0              19877   78.8500          C46
# 62      male  46.0000      1      0        W.E.P. 5734   61.1750          E31
# 63    female  47.0000      1      0        W.E.P. 5734   61.1750          E31
# 64      male  27.0000      1      0             113806   53.1000           E8
# 65    female  33.0000      1      0             113806   53.1000           E8
# 66    female  36.0000      0      0           PC 17608  262.3750          B61
# 67    female  30.0000      0      0             110152   86.5000          B77
# 68      male  45.0000      0      0           PC 17594   29.7000           A9
# 69    female   0.0000      0      1             113505   55.0000          E33
# 70      male   0.0000      0      0             112051    0.0000            0
# 71      male  27.0000      1      0              13508  136.7792          C89
# 72    female  26.0000      1      0              13508  136.7792          C89
# 73    female  22.0000      0      0             113781  151.5500            0
# 74      male   0.0000      0      0             110465   52.0000          A14
# 75      male  47.0000      0      0               5727   25.5875          E58
# 76    female  39.0000      1      1           PC 17756   83.1583          E49
# 77      male  37.0000      1      1           PC 17756   83.1583          E52
# 78    female  64.0000      0      2           PC 17756   83.1583          E45
# 79    female  55.0000      2      0              11770   25.7000         C101
# 80      male   0.0000      0      0             113791   26.5500            0
# 81      male  70.0000      1      1          WE/P 5735   71.0000          B22
# 82    female  36.0000      0      2          WE/P 5735   71.0000          B22
# 83    female  64.0000      1      1             112901   26.5500          B26
# 84      male  39.0000      1      0           PC 17599   71.2833          C85
# 85    female  38.0000      1      0           PC 17599   71.2833          C85
# 86      male  51.0000      0      0             113055   26.5500          E17
# 87      male  27.0000      0      0             113804   30.5000            0
# 88    female  33.0000      0      0             113781  151.5500            0
# 89      male  31.0000      1      0         F.C. 12750   52.0000          B71
# 90    female  27.0000      1      2         F.C. 12750   52.0000          B71
# 91      male  31.0000      1      0              17474   57.0000          B20
# 92    female  17.0000      1      0              17474   57.0000          B20
# 93      male  53.0000      1      1              33638   81.8583          A34
# 94      male   4.0000      0      2              33638   81.8583          A34
# 95    female  54.0000      1      1              33638   81.8583          A34
# 96      male  50.0000      1      0           PC 17761  106.4250          C86
# 97    female  27.0000      1      1           PC 17558  247.5208      B58 B60
# 98    female  48.0000      1      0           PC 17761  106.4250          C86
# 99    female  48.0000      1      0              11755   39.6000          A16
# ...      ...      ...    ...    ...                ...       ...          ...
# 1209  female   2.0000      3      2             347088   27.9000            0
# 1210    male  40.0000      1      4             347088   27.9000            0
# 1211  female  45.0000      1      4             347088   27.9000            0
# 1212    male   0.0000      0      0             349214    7.8958            0
# 1213    male   0.0000      0      0    SOTON/OQ 392086    8.0500            0
# 1214    male   0.0000      0      0             315037    8.6625            0
# 1215    male   0.0000      0      0             384461    7.7500            0
# 1216  female   0.0000      0      0             335432    7.7333            0
# 1217    male  19.0000      0      0             348124    7.6500        F G73
# 1218    male  30.0000      0      0         A.5. 18509    8.0500            0
# 1219    male   0.0000      0      0          A.5. 3236    8.0500            0
# 1220    male  32.0000      0      0    STON/OQ. 369943    8.0500            0
# 1221    male   0.0000      0      0             349208    7.8958            0
# 1222    male  33.0000      0      0             349239    8.6625            0
# 1223  female  23.0000      0      0           CA. 2314    7.5500            0
# 1224    male  21.0000      0      0          A/4 45380    8.0500            0
# 1225    male  60.5000      0      0               3701    0.0000            0
# 1226    male  19.0000      0      0             349205    7.8958            0
# 1227  female  22.0000      0      0               7553    9.8375            0
# 1228    male  31.0000      0      0  STON/O 2. 3101288    7.9250            0
# 1229    male  27.0000      0      0             315083    8.6625            0
# 1230  female   2.0000      0      1             347054   10.4625           G6
# 1231  female  29.0000      1      1             347054   10.4625           G6
# 1232    male  16.0000      0      0    SOTON/OQ 392089    8.0500            0
# 1233    male  44.0000      0      0  STON/O 2. 3101269    7.9250            0
# 1234    male  25.0000      0      0    SOTON/OQ 392076    7.0500            0
# 1235    male  74.0000      0      0             347060    7.7750            0
# 1236    male  14.0000      0      0               7538    9.2250            0
# 1237    male  24.0000      0      0             350035    7.7958            0
# 1238    male  25.0000      0      0             350033    7.7958            0
# 1239    male  34.0000      0      0             363294    8.0500            0
# 1240    male   0.4167      0      1               2625    8.5167            0
# 1241    male   0.0000      1      0               2621    6.4375            0
# 1242    male   0.0000      0      0               2681    6.4375            0
# 1243    male   0.0000      0      0               2684    7.2250            0
# 1244  female  16.0000      1      1               2625    8.5167            0
# 1245    male   0.0000      0      0              32302    8.0500            0
# 1246    male   0.0000      1      0             376564   16.1000            0
# 1247  female   0.0000      1      0             376564   16.1000            0
# 1248    male  32.0000      0      0  STON/O 2. 3101293    7.9250            0
# 1249    male   0.0000      0      0             383121    7.7500          F38
# 1250    male   0.0000      0      0             349216    7.8958            0
# 1251    male  30.5000      0      0             364499    8.0500            0
# 1252    male  44.0000      0      0             364511    8.0500            0
# 1253    male   0.0000      0      0               2673    7.2292            0
# 1254    male  25.0000      0      0               LINE    0.0000            0
# 1255    male   0.0000      0      0               2641    7.2292            0
# 1256    male   7.0000      1      1               2650   15.2458            0
# 1257  female   9.0000      1      1               2650   15.2458            0
# 1258  female  29.0000      0      2               2650   15.2458            0
# 1259    male  36.0000      0      0             349247    7.8958            0
# 1260  female  18.0000      0      0               4138    9.8417            0
# 1261  female  63.0000      0      0               4134    9.5875            0
# 1262    male   0.0000      1      1           A/5. 851   14.5000            0
# 1263    male  11.5000      1      1           A/5. 851   14.5000            0
# 1264    male  40.5000      0      2           A/5. 851   14.5000            0
# 1265  female  10.0000      0      2             345773   24.1500            0
# 1266    male  36.0000      1      1             345773   24.1500            0
# 1267  female  30.0000      1      1             345773   24.1500            0
# 1268    male   0.0000      0      0             345777    9.5000            0
# 1269    male  33.0000      0      0             345780    9.5000            0
# 1270    male  28.0000      0      0             345770    9.5000            0
# 1271    male  28.0000      0      0             345783    9.5000            0
# 1272    male  47.0000      0      0             345765    9.0000            0
# 1273  female  18.0000      2      0             345764   18.0000            0
# 1274    male  31.0000      3      0             345763   18.0000            0
# 1275    male  16.0000      2      0             345764   18.0000            0
# 1276  female  31.0000      1      0             345763   18.0000            0
# 1277    male  22.0000      0      0               2658    7.2250            0
# 1278    male  20.0000      0      0             350416    7.8542            0
# 1279  female  14.0000      0      0             350406    7.8542            0
# 1280    male  22.0000      0      0             349252    7.8958            0
# 1281    male  22.0000      0      0             345767    9.0000            0
# 1282    male   0.0000      0      0             359309    8.0500            0
# 1283    male   0.0000      0      0         C.A. 49867    7.5500            0
# 1284    male   0.0000      0      0   SOTON/OQ 3101316    8.0500            0
# 1285    male  32.5000      0      0             345775    9.5000            0
# 1286  female  38.0000      0      0               2688    7.2292            0
# 1287    male  51.0000      0      0             347064    7.7500            0
# 1288    male  18.0000      1      0            3101267    6.4958            0
# 1289    male  21.0000      1      0            3101266    6.4958            0
# 1290  female  47.0000      1      0             363272    7.0000            0
# 1291    male   0.0000      0      0               3410    8.7125            0
# 1292    male   0.0000      0      0      S.O./P.P. 751    7.5500            0
# 1293    male   0.0000      0      0           A/5 2466    8.0500            0
# 1294    male  28.5000      0      0              54636   16.1000            0
# 1295    male  21.0000      0      0   SOTON/OQ 3101317    7.2500            0
# 1296    male  27.0000      0      0             315154    8.6625            0
# 1297    male   0.0000      0      0         A/4. 34244    7.2500            0
# 1298    male  36.0000      0      0             345771    9.5000            0
# 1299    male  27.0000      1      0               2659   14.4542            0
# 1300  female  15.0000      1      0               2659   14.4542            0
# 1301    male  45.5000      0      0               2628    7.2250            0
# 1302    male   0.0000      0      0               2647    7.2250            0
# 1303    male   0.0000      0      0               2627   14.4583            0
# 1304  female  14.5000      1      0               2665   14.4542            0
# 1305  female   0.0000      1      0               2665   14.4542            0
# 1306    male  26.5000      0      0               2656    7.2250            0
# 1307    male  27.0000      0      0               2670    7.2250            0
# 1308    male  29.0000      0      0             315082    7.8750            0
#
#      embarked   boat   body                                       home.dest  \
# 0           S      2    0.0                                    St Louis, MO
# 1           S     11    0.0                 Montreal, PQ / Chesterville, ON
# 2           S      0    0.0                 Montreal, PQ / Chesterville, ON
# 3           S      0  135.0                 Montreal, PQ / Chesterville, ON
# 4           S      0    0.0                 Montreal, PQ / Chesterville, ON
# 5           S      3    0.0                                    New York, NY
# 6           S     10    0.0                                      Hudson, NY
# 7           S      0    0.0                                     Belfast, NI
# 8           S      D    0.0                             Bayside, Queens, NY
# 9           C      0   22.0                             Montevideo, Uruguay
# 10          C      0  124.0                                    New York, NY
# 11          C      4    0.0                                    New York, NY
# 12          C      9    0.0                                   Paris, France
# 13          S      6    0.0                                               0
# 14          S      B    0.0                                   Hessle, Yorks
# 15          S      0    0.0                                    New York, NY
# 16          C      0    0.0                                    Montreal, PQ
# 17          C      6    0.0                                    Montreal, PQ
# 18          C      8    0.0                                               0
# 19          C      A    0.0                                    Winnipeg, MN
# 20          S      5    0.0                                    New York, NY
# 21          S      5    0.0                                    New York, NY
# 22          C      5    0.0                                    New York, NY
# 23          C      4    0.0                                               0
# 24          S      8    0.0                                               0
# 25          C      0  148.0                               San Francisco, CA
# 26          C      7    0.0                                    Dowagiac, MI
# 27          C      7    0.0                                    Dowagiac, MI
# 28          S      8    0.0                                               0
# 29          S      D    0.0              Stockholm, Sweden / Washington, DC
# 30          S      0    0.0                                     Trenton, NJ
# 31          C      7    0.0                                  Glen Ridge, NJ
# 32          S      8    0.0                                  Youngstown, OH
# 33          S      8    0.0               Birkdale, England Cleveland, Ohio
# 34          S      0    0.0                           London / Winnipeg, MB
# 35          C      4    0.0                                 Cooperstown, NY
# 36          S      6    0.0                St Leonards-on-Sea, England Ohio
# 37          S      9    0.0                                 Los Angeles, CA
# 38          S      0    0.0                                     Pomeroy, WA
# 39          C      0  208.0                                       Omaha, NE
# 40          C      0    0.0                                Philadelphia, PA
# 41          C      6    0.0                                      Denver, CO
# 42          S      D    0.0                                     Belmont, MA
# 43          C      8    0.0                                Philadelphia, PA
# 44          C      3    0.0                                               0
# 45          S      0    0.0                                  Washington, DC
# 46          S      0    0.0                                               0
# 47          S      5    0.0                                    New York, NY
# 48          C      6    0.0                                  Washington, DC
# 49          C      3    0.0  Austria-Hungary / Germantown, Philadelphia, PA
# 50          C      3    0.0                    Germantown, Philadelphia, PA
# 51          S      0    0.0                                    New York, NY
# 52          S      0    0.0                             Montevideo, Uruguay
# 53          S      0    0.0                             Montevideo, Uruguay
# 54          S      4    0.0                                   Bryn Mawr, PA
# 55          S      4    0.0                                   Bryn Mawr, PA
# 56          S      C    0.0                                   Bryn Mawr, PA
# 57          S      4    0.0                                   Bryn Mawr, PA
# 58          S      0    0.0                Ascot, Berkshire / Rochester, NY
# 59          C      5    0.0                                    New York, NY
# 60          S      0  172.0                         Little Onn Hall, Staffs
# 61          S      6    0.0                         Little Onn Hall, Staffs
# 62          S      0    0.0                                      Amenia, ND
# 63          S      4    0.0                                      Amenia, ND
# 64          S      5    0.0                       New York, NY / Ithaca, NY
# 65          S      5    0.0                       New York, NY / Ithaca, NY
# 66          C      4    0.0                                               0
# 67          S      8    0.0                                 London, England
# 68          C      7    0.0                                   Paris, France
# 69          S      6    0.0                St Leonards-on-Sea, England Ohio
# 70          S      0    0.0                    Liverpool, England / Belfast
# 71          C      0    0.0                                 Los Angeles, CA
# 72          C      4    0.0                                 Los Angeles, CA
# 73          S     11    0.0                                               0
# 74          S      0    0.0                                   Stoughton, MA
# 75          S      0    0.0                                    Victoria, BC
# 76          C     14    0.0                                    Lakewood, NJ
# 77          C      0    0.0                                    Lakewood, NJ
# 78          C     14    0.0                                    Lakewood, NJ
# 79          S      2    0.0                                    New York, NY
# 80          S      0    0.0                                   Roachdale, IN
# 81          S      0  269.0                                   Milwaukee, WI
# 82          S      7    0.0                                   Milwaukee, WI
# 83          S      7    0.0                                   Milwaukee, WI
# 84          C      0    0.0                                    New York, NY
# 85          C      4    0.0                                    New York, NY
# 86          S    5 9    0.0                                      Lima, Peru
# 87          S      3    0.0                                Philadelphia, PA
# 88          S      8    0.0                                               0
# 89          S      0    0.0                                    Montreal, PQ
# 90          S      3    0.0                                    Montreal, PQ
# 91          S      3    0.0                                     Calgary, AB
# 92          S      3    0.0                                     Calgary, AB
# 93          S     13    0.0                               San Francisco, CA
# 94          S      5    0.0                               San Francisco, CA
# 95          S      5    0.0                               San Francisco, CA
# 96          C      0   62.0                Deephaven, MN / Cedar Rapids, IA
# 97          C      6    0.0                                    Montreal, PQ
# 98          C      2    0.0                Deephaven, MN / Cedar Rapids, IA
# 99          C      1    0.0                                  London / Paris
# ...       ...    ...    ...                                             ...
# 1209        S      0    0.0                                               0
# 1210        S      0    0.0                                               0
# 1211        S      0    0.0                                               0
# 1212        S      0    0.0                                               0
# 1213        S      0    0.0                                               0
# 1214        S      0    0.0                                               0
# 1215        Q      0    0.0                                               0
# 1216        Q     13    0.0                                               0
# 1217        S      0    0.0                                               0
# 1218        S      0    0.0                                               0
# 1219        S      0    0.0                                               0
# 1220        S      0    0.0                                               0
# 1221        S      0    0.0                                               0
# 1222        C      0    0.0                                               0
# 1223        S      C    0.0                                               0
# 1224        S      0    0.0                                               0
# 1225        S      0  261.0                                               0
# 1226        S      0    0.0                                               0
# 1227        S      0    0.0                                               0
# 1228        S      9    0.0                                               0
# 1229        S      0    0.0                                               0
# 1230        S      0    0.0                                               0
# 1231        S      0    0.0                                               0
# 1232        S      B    0.0                                               0
# 1233        S     15    0.0                                               0
# 1234        S      0    0.0                                               0
# 1235        S      0    0.0                                               0
# 1236        S     13    0.0                                               0
# 1237        S      0    0.0                                               0
# 1238        S  13 15    0.0                                               0
# 1239        S      0  176.0                                               0
# 1240        C     16    0.0                                               0
# 1241        C      0    0.0                                               0
# 1242        C      0    0.0                                               0
# 1243        C      0    0.0                                               0
# 1244        C     14    0.0                                               0
# 1245        S      0    0.0                                               0
# 1246        S      0    0.0                                               0
# 1247        S     10    0.0                                               0
# 1248        S      0    0.0                                               0
# 1249        Q      0    0.0                                               0
# 1250        S      0    0.0                                               0
# 1251        S      0   50.0                                               0
# 1252        S      0    0.0                                               0
# 1253        C      0    0.0                                               0
# 1254        S     15    0.0                                               0
# 1255        C      0    0.0                                               0
# 1256        C      C    0.0                                               0
# 1257        C      C    0.0                                               0
# 1258        C      C    0.0                                               0
# 1259        S      0    0.0                                               0
# 1260        S     15    0.0                                               0
# 1261        S     15    0.0                                               0
# 1262        S      0    0.0                                               0
# 1263        S      0    1.0                                               0
# 1264        S      0  255.0                                               0
# 1265        S      0    0.0                                               0
# 1266        S      0    0.0                                               0
# 1267        S      0    0.0                                               0
# 1268        S      0    0.0                                               0
# 1269        S      0    0.0                                               0
# 1270        S      0    0.0                                               0
# 1271        S      0    0.0                                               0
# 1272        S      0    0.0                                               0
# 1273        S      0    0.0                                               0
# 1274        S      0    0.0                                               0
# 1275        S      0    0.0                                               0
# 1276        S      0    0.0                                               0
# 1277        C  13 15    0.0                                               0
# 1278        S      0    0.0                                               0
# 1279        S      0    0.0                                               0
# 1280        S      0    0.0                                               0
# 1281        S      0    0.0                  Antwerp, Belgium / Stanton, OH
# 1282        S      0    0.0                                               0
# 1283        S      0    0.0                                               0
# 1284        S      0    0.0                                               0
# 1285        S      0  298.0                                               0
# 1286        C      C    0.0                                               0
# 1287        S      0    0.0                                               0
# 1288        S      0  314.0                                               0
# 1289        S      0    0.0                                               0
# 1290        S      0    0.0                                               0
# 1291        S      0    0.0                                               0
# 1292        S      0    0.0                                               0
# 1293        S      0    0.0                                               0
# 1294        S      0   14.0                                               0
# 1295        S      0    0.0                                               0
# 1296        S      0  131.0                                               0
# 1297        S      0    0.0                                               0
# 1298        S      0    0.0                                               0
# 1299        C      C    0.0                                               0
# 1300        C      0    0.0                                               0
# 1301        C      0  312.0                                               0
# 1302        C      0    0.0                                               0
# 1303        C      0    0.0                                               0
# 1304        C      0  328.0                                               0
# 1305        C      0    0.0                                               0
# 1306        C      0  304.0                                               0
# 1307        C      0    0.0                                               0
# 1308        S      0    0.0                                               0
#
#                    only_name
# 0                      Allen
# 1                    Allison
# 2                    Allison
# 3                    Allison
# 4                    Allison
# 5                   Anderson
# 6                    Andrews
# 7                    Andrews
# 8                   Appleton
# 9               Artagaveytia
# 10                     Astor
# 11                     Astor
# 12                    Aubart
# 13                    Barber
# 14                 Barkworth
# 15                   Baumann
# 16                    Baxter
# 17                    Baxter
# 18                   Bazzani
# 19                   Beattie
# 20                  Beckwith
# 21                  Beckwith
# 22                      Behr
# 23                    Bidois
# 24                      Bird
# 25                  Birnbaum
# 26                    Bishop
# 27                    Bishop
# 28                  Bissette
# 29    Bjornstrom-Steffansson
# 30                 Blackwell
# 31                     Blank
# 32                   Bonnell
# 33                   Bonnell
# 34                  Borebank
# 35                     Bowen
# 36                  Bowerman
# 37                   Bradley
# 38                     Brady
# 39                  Brandeis
# 40                     Brewe
# 41                     Brown
# 42                     Brown
# 43                  Bucknell
# 44                     Burns
# 45                      Butt
# 46                    Cairns
# 47                Calderhead
# 48                    Candee
# 49                   Cardeza
# 50                   Cardeza
# 51                  Carlsson
# 52                    Carrau
# 53                    Carrau
# 54                    Carter
# 55                    Carter
# 56                    Carter
# 57                    Carter
# 58                      Case
# 59                 Cassebeer
# 60                 Cavendish
# 61                 Cavendish
# 62                   Chaffee
# 63                   Chaffee
# 64                  Chambers
# 65                  Chambers
# 66                Chaudanson
# 67                    Cherry
# 68                    Chevre
# 69                  Chibnall
# 70                  Chisholm
# 71                     Clark
# 72                     Clark
# 73                   Cleaver
# 74                  Clifford
# 75                    Colley
# 76                   Compton
# 77                   Compton
# 78                   Compton
# 79                   Cornell
# 80                   Crafton
# 81                    Crosby
# 82                    Crosby
# 83                    Crosby
# 84                   Cumings
# 85                   Cumings
# 86                      Daly
# 87                    Daniel
# 88                   Daniels
# 89                  Davidson
# 90                  Davidson
# 91                      Dick
# 92                      Dick
# 93                     Dodge
# 94                     Dodge
# 95                     Dodge
# 96                   Douglas
# 97                   Douglas
# 98                   Douglas
# 99               Duff Gordon
# ...                      ...
# 1209                   Skoog
# 1210                   Skoog
# 1211                   Skoog
# 1212               Slabenoff
# 1213               Slocovski
# 1214               Smiljanic
# 1215                   Smith
# 1216                   Smyth
# 1217                  Soholt
# 1218                Somerton
# 1219                 Spector
# 1220                 Spinner
# 1221                 Staneff
# 1222               Stankovic
# 1223                 Stanley
# 1224                 Stanley
# 1225                  Storey
# 1226              Stoytcheff
# 1227              Strandberg
# 1228                Stranden
# 1229                 Strilic
# 1230                   Strom
# 1231                   Strom
# 1232              Sunderland
# 1233                 Sundman
# 1234                Sutehall
# 1235                Svensson
# 1236                Svensson
# 1237                Svensson
# 1238                 Tenglin
# 1239                Theobald
# 1240                  Thomas
# 1241                  Thomas
# 1242                  Thomas
# 1243                  Thomas
# 1244                  Thomas
# 1245                 Thomson
# 1246            Thorneycroft
# 1247            Thorneycroft
# 1248                Tikkanen
# 1249                   Tobin
# 1250                Todoroff
# 1251                  Tomlin
# 1252                  Torber
# 1253                   Torfa
# 1254               Tornquist
# 1255                  Toufik
# 1256                   Touma
# 1257                   Touma
# 1258                   Touma
# 1259                  Turcin
# 1260                   Turja
# 1261                 Turkula
# 1262            van Billiard
# 1263            van Billiard
# 1264            van Billiard
# 1265                Van Impe
# 1266                Van Impe
# 1267                Van Impe
# 1268           van Melkebeke
# 1269             Vande Velde
# 1270             Vande Walle
# 1271            Vanden Steen
# 1272         Vander Cruyssen
# 1273           Vander Planke
# 1274           Vander Planke
# 1275           Vander Planke
# 1276           Vander Planke
# 1277               Vartanian
# 1278                  Vendel
# 1279                 Vestrom
# 1280                    Vovk
# 1281                 Waelens
# 1282                    Ware
# 1283                  Warren
# 1284                  Webber
# 1285                  Wenzel
# 1286                  Whabee
# 1287                Widegren
# 1288                 Wiklund
# 1289                 Wiklund
# 1290                  Wilkes
# 1291                  Willer
# 1292                  Willey
# 1293                Williams
# 1294                Williams
# 1295                Windelov
# 1296                    Wirz
# 1297                 Wiseman
# 1298            Wittevrongel
# 1299                 Yasbeck
# 1300                 Yasbeck
# 1301                 Youseff
# 1302                  Yousif
# 1303                Yousseff
# 1304                  Zabour
# 1305                  Zabour
# 1306                Zakarian
# 1307                Zakarian
# 1308               Zimmerman
#
# [1309 rows x 15 columns]

# %% [markdown]
# # 4. Группировка

# %% [markdown]
# ![](https://image.slidesharecdn.com/slides-151008060416-lva1-app6892/95/pandas-powerful-data-analysis-tools-for-python-19-638.jpg?cb=1444284343)

# %%
titanik_csv.groupby('sex')

# %%
titanik_csv.groupby('sex').age

# %%
titanik_csv.groupby('sex').age.mean()
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
titanik_csv.groupby(['sex', 'pclass']).age.mean()
# Out:
# sex     pclass
# female  1         37.037594
#         2         27.499191
#         3         22.185307
# male    1         41.029250
#         2         30.815401
#         3         25.962273
# Name: age, dtype: float64

# %%
# Я делаль, хотел поюзать agregate({''})

titanik_csv.groupby(['sex', 'pclass']).age.mean()

# %%
titanik_csv.groupby(['sex', 'pclass']).age.apply( lambda x: np.mean(x) )
# Out:
# sex     pclass
# female  1         37.037594
#         2         27.499191
#         3         22.185307
# male    1         41.029250
#         2         30.815401
#         3         25.962273
# Name: age, dtype: float64

# %%
titanik_csv.groupby(['sex', 'pclass']).age.mean().reset_index()
# Out:
#       sex  pclass        age
# 0  female       1  37.037594
# 1  female       2  27.499191
# 2  female       3  22.185307
# 3    male       1  41.029250
# 4    male       2  30.815401
# 5    male       3  25.962273

# %%
titanik_csv.groupby(['pclass']).fare.mean().reset_index()
# Out:
#    pclass       fare
# 0       1  87.508992
# 1       2  21.179196
# 2       3  13.302889

# %% [markdown]
# ##### Слияние двух датафреймов

# %%
a = titanik_csv.groupby(['sex', 'pclass']).age.mean().reset_index()
b = titanik_csv.groupby(['pclass']).fare.mean().reset_index()

# %%
a
# Out:
#       sex  pclass        age
# 0  female       1  37.037594
# 1  female       2  27.499191
# 2  female       3  22.185307
# 3    male       1  41.029250
# 4    male       2  30.815401
# 5    male       3  25.962273

# %%
b
# Out:
#    pclass       fare
# 0       1  87.508992
# 1       2  21.179196
# 2       3  13.302889

# %%
pd.merge(a, b, on='pclass')
# Out:
#       sex  pclass        age       fare
# 0  female       1  37.037594  87.508992
# 1    male       1  41.029250  87.508992
# 2  female       2  27.499191  21.179196
# 3    male       2  30.815401  21.179196
# 4  female       3  22.185307  13.302889
# 5    male       3  25.962273  13.302889

# %%
c = pd.merge(a, b, on='pclass')

# %%
## как удалить из c колонку age ?

# %%
## как удалить из c строчки с индексами 2 и 4 ?

# %% [markdown]
# ##### Таблица сопряженности

# %% [markdown]
# Давайте построим **таблицу сопряженности** (Она же **cross tabulation** или **contigency table** она же **pivot table**).
#
# https://en.wikipedia.org/wiki/Contingency_table
#
# Pandas позволяет сложные таблицы сопряженности со многими уровнями вложенности с использованием функции pandas .crosstab()
#
# Нам потребуются 2 параметра этой функции:
#
# 1. index - список колонок которые будут расположены по вертикали (список может состоять из 1 элемента)
# 2. columns - список колонок которые будут расположены по горизонтали (список может состоять из 1 элемента)
# Опционально (использовать отдельно друго от друга)
# 3. margins - значение True будет показывать сумму по столбцам и строкам
# 4. normalize - новый параметр позволят отнормировать значения на сумму по строке ('rows'), столбцу ('columns'), или на ту и другую ('all')
#
# Обратите внимание что crosstab() это функция библиотеки Pandas, а не метод
# объекта pandas.DataFrame.
#
# Может быть не очень понятно как ее использовать, если не сможете разобраться, ответ можно найти тут  https://www.kaggle.com/dejavu23/titanic-eda-to-ml-beginner .
# **Но сначала попробуйте погуглить.**
#
# Документация на .crosstab()
# http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html

# %%
# воспользуйтесь функцией crosstab() и построите таблицу сопряженности
# для колнок Sex (по вертикали) и Survived (по горизонтали)

pd.crosstab(index=titanik_csv.survived, columns=titanik_csv.sex)
# Out:
# sex       female  male
# survived
# 0            127   682
# 1            339   161

# %% [raw]
# должно получиться что-то типа такого
# array([[127, 339],
#        [682, 161]])

# %%
# воспользуйтесь функцией crosstab() и построите таблицу сопряженности 
# для колнок Sex и Survived (по вертикали) и Pclass (по горизонтали)
# установите параметр margins=True

pd.crosstab( ... )

# %% [raw]
# должно получиться что-то типа такого
#
# array([[   5,   12,  110,  127],
#        [ 118,  146,  418,  682],
#        [ 139,   94,  106,  339],
#        [  61,   25,   75,  161],
#        [ 323,  277,  709, 1309]])

# %% [markdown]
# #### Вопрос:
# Что вы можете сказать выживаемости пассижиров разного класса и пола?

# %% [markdown]
# .crosstab() позволяет не только считать количество внутри категорий,
# у него есть специальный параметр:
# 1. values - можно передать сюда столбец для которого будет посчитана aggfunc внутри сложной категории задаваемой вашей таблице

# %%
# Построим предыдующую таблицу
# но теперь воспользуемся параметрами values (titanic['age']) и aggfunc ('mean')

pd.crosstab(index=[titanik_csv.survived, titanik_csv['sex']],
            columns=[titanik_csv.pclass],
            values=titanik_csv['age'],
            aggfunc='mean',
            margins=True)
# Out:
# pclass                   1          2          3        All
# survived sex
# 0        female  35.200000  34.090909  23.418750  25.255208
#          male    43.658163  33.092593  26.679598  31.516412
# 1        female  37.109375  26.711051  20.814815  29.815354
#          male    36.168240  17.449274  22.436441  26.977778
# All              39.159918  29.506705  24.816367  29.881135

# %%
pd.crosstab(titanik_csv.survived,
            titanik_csv.pclass)
# Out:
# pclass      1    2    3
# survived
# 0         123  158  528
# 1         200  119  181

# %%
pd.pivot_table(titanik_csv, values='sex', index='survived', columns='pclass', aggfunc='count')
# Out:
# pclass      1    2    3
# survived
# 0         123  158  528
# 1         200  119  181

# %% [markdown]
# # Визуализация
#
# кто любит поинтереснее - Seaborn for the Titanic
# https://gist.github.com/mwaskom/8224591

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(-1, 1, 100)

plt.plot(x, x**2, '-b')

# %%
plt.scatter(x, x**2, c=['r' if int(i * 10) % 2 == 1 else 'b' for i in x])

# %%
plt.scatter(x, np.random.randn(100), c=['r' if int(i * 10) % 2 == 1 else 'b' for i in x])

# %%
idx = [1,2,3,4]
vals = [100, 150, 200, 345]

plt.bar(idx, vals, tick_label=['a', 'b', 'g', 'dsd']);

# %%
plt.hist(np.random.randn(10000), bins=100);

# %%
plt.figure(figsize=(12, 4))

plt.hist(np.random.randn(10000), bins=100, label='norm_disr')

plt.legend(loc=[1.1, 0.8]) # try loc='best'

plt.title('my_title is beautiful');

# plt.xlim([-3, 3])
# plt.ylim([-100, 400])

plt.xlabel('my bins');
plt.ylabel('my counters');

# plt.xticks(np.arange(-3, 4, 1), list('abcdefg'))
# plt.yticks()

# plt.savefig('./path.png', dpi=300)

# %%
## TODO нарисуем несколько графиков на одном - квадратичную и кубическую зависимость
## Подпишем графики и выведем легенду чтобы было понятно какой график - какой.

x = np.linspace(-1, 1, 100)

plt. ...

# %% [markdown]
# ##### Несколько графиков рядом

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# subplot - сетка с высотой 2 и шириной 1, по дефолту сделать первый subplot активным
plt.subplot(2, 1, 1)

# построим что нибудь на первом
plt.plot(x, y_sin)
plt.title('Sine')

# Поменяем сабплот - теперь активен второй
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# отрисовать
plt.show()

# %% [markdown]
# # Посмотрим на титанике

# %%
import pandas as pd

# %%
titanic =  pd.read_csv('titanik.tsv', sep='|', index_col=0)

# %%
titanic["pclass"].value_counts()

# %% [markdown]
# Отрисуем pclass

# %%
plt.bar( titanic["pclass"].value_counts().index, 
         titanic["pclass"].value_counts().values,
         tick_label=titanic["pclass"].value_counts().index);

# %% [markdown]
# посмотрим на число погибших людей в каждом из pclass

# %%
titanic.loc[titanic.survived==0, "pclass"].value_counts()

# %%
pd.crosstab(titanic.survived, titanic.pclass)

# %%
died = pd.crosstab(titanic.survived, titanic.pclass).loc[0]
plt.bar(died.index, died.values);

# %% [markdown]
# Попробуем в зависимости от пола

# %%
male = titanic.sex=='male'

survived = pd.crosstab(titanic[male].survived, 
                       titanic[male].pclass
                      ).loc[1]
plt.bar(survived.index, survived.values, alpha=0.4, label='male');


survived = pd.crosstab(titanic[~male].survived, 
                       titanic[~male].pclass
                      ).loc[1]
plt.bar(survived.index, survived.values, alpha=0.4, label='female');

# %%
titanic.sex.value_counts()

# %%
titanic[titanic.survived==1].sex.value_counts()

# %%
male_age = titanic[titanic.sex=='male'].age.dropna()
female_age = titanic[titanic.sex!='male'].age.dropna()

bins = plt.hist(female_age, color='orange', alpha=0.5, label='female')
bins = plt.hist(male_age, bins=bins[1], color='blue', alpha=0.5, label='male')
plt.legend(loc='best')

plt.title('распределение возрастов мужчин и женщин');

# %%
male_age = titanic[(titanic.sex=='male').values * (titanic.survived==1).values].age.dropna()
female_age = titanic[(titanic.sex=='female').values * (titanic.survived==1).values].age.dropna()

bins = plt.hist(female_age, color='orange', alpha=0.5, label='female')
bins = plt.hist(male_age, bins=bins[1], color='blue', alpha=0.5, label='male')
plt.legend(loc='best')

plt.title('распределение возрастов мужчин и женщин среди выживших');

# %%
plt.scatter(titanic.age, titanic.fare, c=titanic.sex.apply(lambda x: 'r' if x=='female' else 'b'))

# %%
maps = {1:'r', 2:'b', 3:'y'}
plt.scatter(titanic[titanic.pclass==1].age, titanic[titanic.pclass==1].fare, c='r', label='first_class')
plt.scatter(titanic[titanic.pclass==2].age, titanic[titanic.pclass==2].fare, c='b', label='second_class')
plt.scatter(titanic[titanic.pclass==3].age, titanic[titanic.pclass==3].fare, c='y', label='third_class')

plt.xlabel('age')
plt.ylabel('fare')

plt.legend()

# %% [markdown]
# > все достаточно логично, однако если бы данные не были такими очевидными?

# %%
plt.scatter(titanic.index, titanic.fare)

# %% [markdown]
# https://khashtamov.com/ru/pandas-introduction/

# %% [markdown]
# https://seaborn.pydata.org/tutorial.html
