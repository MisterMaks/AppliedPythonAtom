# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # STEP 1. Скачайте датасет.
#
# Download the Adult training data set: http://archive.ics.uci.edu/ml/datasets/Adult
# (file adult.data)

# %%
# !wget http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
# Out:
# /bin/sh: wget: command not found

# %%
# !head adult.data
# Out:
# 39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K
# 50, Self-emp-not-inc, 83311, Bachelors, 13, Married-civ-spouse, Exec-managerial, Husband, White, Male, 0, 0, 13, United-States, <=50K
# 38, Private, 215646, HS-grad, 9, Divorced, Handlers-cleaners, Not-in-family, White, Male, 0, 0, 40, United-States, <=50K
# 53, Private, 234721, 11th, 7, Married-civ-spouse, Handlers-cleaners, Husband, Black, Male, 0, 0, 40, United-States, <=50K
# 28, Private, 338409, Bachelors, 13, Married-civ-spouse, Prof-specialty, Wife, Black, Female, 0, 0, 40, Cuba, <=50K
# 37, Private, 284582, Masters, 14, Married-civ-spouse, Exec-managerial, Wife, White, Female, 0, 0, 40, United-States, <=50K
# 49, Private, 160187, 9th, 5, Married-spouse-absent, Other-service, Not-in-family, Black, Female, 0, 0, 16, Jamaica, <=50K
# ...

# %% [markdown]
# # Step 2. Поймите формат и зачитайте adult.data в переменную df. Используйте cols чтобы дать нормальные названия колонкам.
#
# Обратите внимание на формат!

# %%
cols = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'result']

# %%
df = pd.read_csv('./adult.data', sep=', ', names=cols)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country result
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# # Сколько мужчин и женщин?

# %%
df.sex.value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %% [markdown]
# # Средний возраст мужчин и женщин?

# %%
df.groupby('sex').age.mean()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %% [markdown]
# # Какая доля граждан США (United-States) в данном датасете?

# %%
df['native-country'].value_counts()['United-States']/df['native-country'].count()
# Out:
# 0.895857006848684

# %% [markdown]
# # Нарисуйте распределние образования людей (используйте bar plot)
#
# Подпишите график и оси.

# %%
x = list(df['education'].value_counts().keys())
y = list(df['education'].value_counts())
plt.figure(figsize=(20,10), dpi=300)
plt.title("РАСПРЕДЕЛЕНИЕ ОБРАЗОВАНИЯ ЛЮДЕЙ", fontsize=30, fontweight='heavy')
plt.ylabel('COUNT OF PEOPLE', fontsize=30, fontweight='heavy')
plt.xlabel('EDUCATION', fontsize=30, fontweight='heavy')
plt.bar(x, y);
plt.tick_params(axis='x', labelsize=15, labelrotation=45)
plt.tick_params(axis='y', labelsize=15)

# %% [markdown]
# # Какое среднее значние и квадратичное отклонение (std) fnlwgt (”final weight”) разведенных (divorced people) людей. Нарисуйте гистрограмму (Какое распределение оно вам напоминает?)

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df1 = df.loc[:, ["fnlwgt","marital-status"]]
df1
# Out:
#        fnlwgt         marital-status
# 0       77516          Never-married
# 1       83311     Married-civ-spouse
# 2      215646               Divorced
# 3      234721     Married-civ-spouse
# 4      338409     Married-civ-spouse
# 5      284582     Married-civ-spouse
# 6      160187  Married-spouse-absent
# 7      209642     Married-civ-spouse
# 8       45781          Never-married
# 9      159449     Married-civ-spouse
# 10     280464     Married-civ-spouse
# 11     141297     Married-civ-spouse
# 12     122272          Never-married
# 13     205019          Never-married
# 14     121772     Married-civ-spouse
# 15     245487     Married-civ-spouse
# 16     176756          Never-married
# 17     186824          Never-married
# 18      28887     Married-civ-spouse
# 19     292175               Divorced
# 20     193524     Married-civ-spouse
# 21     302146              Separated
# 22      76845     Married-civ-spouse
# 23     117037     Married-civ-spouse
# ...

# %%
df1[df1['marital-status']=='Divorced']['fnlwgt']
# Out:
# 2        215646
# 19       292175
# 24       109015
# 28       367260
# 32       386940
# 47       128354
# 53       251585
# 54       109832
# 64       105598
# 66       183175
# 84       343591
# 85       346253
# 91       286730
# 92       212563
# 98       171095
# 129      365739
# 134      146195
# 149      174662
# 150      186009
# 154      252903
# 158      191535
# 160       38317
# 162       78374
# 165      207157
# 181      114580
# 186      143129
# 187      135105
# 190      155222
# 196       99374
# 204       48211
#           ...
# 32404    379959
# 32412    149620
# 32414     83742
# 32422    161950
# 32427    206878
# 32429    203334
# 32431    274502
# 32432    208068
# 32454    257933
# 32470    485710
# 32471    185647
# 32473    160467
# 32477    114648
# 32484    268083
# 32490    134152
# 32491     63079
# 32492    217597
# 32493    381895
# 32500     60567
# 32504    208630
# 32508    155093
# 32516    176175
# 32523     77266
# 32525    120478
# ...

# %%
list_df1_fnlwgt_Divorced = list(df1[df1['marital-status']=='Divorced']['fnlwgt'])
list_df1_fnlwgt_Divorced
# Out:
# [215646,
#  292175,
#  109015,
#  367260,
#  386940,
#  128354,
#  251585,
#  109832,
#  105598,
#  183175,
#  343591,
#  346253,
#  286730,
#  212563,
#  171095,
#  365739,
#  146195,
#  174662,
#  186009,
#  252903,
#  191535,
#  38317,
#  78374,
#  207157,
#  114580,
#  143129,
#  135105,
#  155222,
#  99374,
#  48211,
#  36270,
#  313321,
#  187656,
#  24215,
#  176796,
#  130408,
#  110978,
#  179488,
#  204518,
#  150042,
#  70377,
#  175413,
#  173960,
#  176609,
#  127595,
#  57424,
#  169469,
#  173321,
#  205607,
#  186110,
#  151989,
#  174575,
#  212448,
#  481060,
#  80914,
#  174319,
#  214955,
#  108699,
#  96975,
#  227689,
#  42346,
#  118500,
#  92440,
#  240283,
#  188401,
#  45857,
#  35598,
#  49401,
#  164427,
#  371373,
#  187251,
#  343121,
#  180980,
#  91996,
#  189346,
#  248344,
#  177905,
#  99183,
#  109339,
#  245724,
#  319560,
#  87490,
#  28738,
#  103948,
#  51290,
#  200853,
#  75654,
#  402089,
#  341204,
#  110457,
#  136721,
#  295566,
# ...

# %%
df1_mean = df1.groupby('marital-status')['fnlwgt'].mean()['Divorced']
df1_std = df1.groupby('marital-status')['fnlwgt'].std()['Divorced']
print(f"Среднее значение fnlwgt разведенных = {df1_mean}")
print(f"Квадратичное отклонение fnlwgt разведенных = {df1_std}")
# Out:
# Среднее значение fnlwgt разведенных = 185802.79045689848
# Квадратичное отклонение fnlwgt разведенных = 105646.78945933616

# %%
plt.figure(figsize=(20,10), dpi=300)
plt.hist(list_df1_fnlwgt_Divorced, bins=75, label='fnlwgt_Divorced_disr')
plt.legend(loc='best')
plt.title('true hist');

# %% [markdown]
# > Ответ: оно мне напоминает распределение Пуассона, Хи^2 или Фишера

# %% [markdown]
# # Правда ли, что большинство людей, из тех кто получает больше 50k, с высшим образованием  (BSc, MSc, PhD - ????)

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df2 = df.loc[:, ['education', 'result']]
df2_b50 = df2[df2['result']=='>50K']['education'].value_counts()
df2_he = df2_b50['Bachelors'] + df2_b50['Masters'] + df2_b50['Doctorate']
df2_he_part = df2_he / df2.shape[0]
df2_he_part
# Out:
# 0.10706059396210191

# %% [markdown]
# > Ответ: Нет.

# %% [markdown]
# # Сколько в среднем работают люди в неделю в зависимости от education?

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df.groupby('education')['hours-per-week'].mean()
# Out:
# education
# 10th            37.052519
# 11th            33.925957
# 12th            35.780600
# 1st-4th         38.255952
# 5th-6th         38.897898
# 7th-8th         39.366873
# 9th             38.044747
# Assoc-acdm      40.504217
# Assoc-voc       41.610709
# Bachelors       42.614006
# Doctorate       46.973366
# HS-grad         40.575374
# Masters         43.836332
# Preschool       36.647059
# Prof-school     47.425347
# Some-college    38.852284
# Name: hours-per-week, dtype: float64

# %% [markdown]
# # Кто больше работает в неделю - мужчины или женщины?

# %%
df.groupby('sex')['hours-per-week'].mean()
# Out:
# sex
# Female    36.410361
# Male      42.428086
# Name: hours-per-week, dtype: float64

# %% [markdown]
# мужчины

# %% [markdown]
# # Кто больше работает в неделю - те кто в отношениях или те кто нет?

# %%
import copy
df3 = copy.deepcopy(df)
df3
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df3.groupby('relationship')['hours-per-week'].mean()
# Out:
# relationship
# Husband           44.120139
# Not-in-family     40.595665
# Other-relative    37.006116
# Own-child         33.269337
# Unmarried         39.103018
# Wife              36.861607
# Name: hours-per-week, dtype: float64

# %%
df3['bin-relationship'] = df3['relationship'].apply \
(lambda x: 'in relationship' if x == 'Husband' or x == 'Wife' else 'not in relationship')
df3
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
df3.groupby('bin-relationship')['hours-per-week'].mean()
# Out:
# bin-relationship
# in relationship        43.349096
# not in relationship    38.022921
# Name: hours-per-week, dtype: float64

# %% [markdown]
# В неделю больше работают те, кто в отношениях

# %% [markdown]
# # Из каких стран люди работают farmers/fishers?

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
list(df[df['occupation']=='Farming-fishing']['native-country'].unique())
# Out:
# ['United-States',
#  'Cambodia',
#  'Poland',
#  'Guatemala',
#  'Mexico',
#  'England',
#  '?',
#  'Philippines',
#  'Italy',
#  'Puerto-Rico',
#  'Vietnam',
#  'Germany',
#  'Japan',
#  'Canada',
#  'Yugoslavia',
#  'Cuba',
#  'Portugal',
#  'El-Salvador',
#  'Hong',
#  'Ireland',
#  'France']

# %% [markdown]
# # Сколько максимум работают люди в неделю? Как много таких людей кто работает наибольшее количество часов? Какой у них доход (распечатать)?

# %%
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
max(df['hours-per-week'])
# Out:
# 99

# %%
df[df['hours-per-week']==max(df['hours-per-week'])].shape[0]
# Out:
# 85

# %%
pd.DataFrame(df[df['hours-per-week']==max(df['hours-per-week'])]['result'])
# Out:
#       result
# 935     >50K
# 1172    >50K
# 1887    >50K
# 3578    >50K
# 4086   <=50K
# 4308   <=50K
# 4441    >50K
# 5376   <=50K
# 5432   <=50K
# 6618   <=50K
# 6898   <=50K
# 8072   <=50K
# 8393    >50K
# 8654   <=50K
# 8796    >50K
# 9811   <=50K
# 9831   <=50K
# 10143  <=50K
# 10266  <=50K
# 10468  <=50K
# 10986   >50K
# 11833  <=50K
# 12209  <=50K
# 12625  <=50K
# 12788  <=50K
# 13558   >50K
# 13580  <=50K
# 13617  <=50K
# 13858   >50K
# 14593  <=50K
# ...      ...
# 23226  <=50K
# 23398  <=50K
# 23649   >50K
# 23830  <=50K
# 24483   >50K
# 25354  <=50K
# 25713   >50K
# 25806  <=50K
# 25831   >50K
# 25986  <=50K
# 26250  <=50K
# 26596   >50K
# 26638  <=50K
# 26858  <=50K
# 27222  <=50K
# 27764  <=50K
# 27809  <=50K
# 28112  <=50K
# 29187   >50K
# 29751  <=50K
# 29989   >50K
# 30036   >50K
# 30610   >50K
# 30754  <=50K
# 30766   >50K
# 30992  <=50K
# 31681   >50K
# 31699  <=50K
# 32469  <=50K
# 32531  <=50K
#
# [85 rows x 1 columns]
